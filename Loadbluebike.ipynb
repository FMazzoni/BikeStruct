# %% [markdown]
# # Loading Blue Bike Boston Dataset
#
#
# The dataset is broken down as:
#
#
# Blue Bikes Comprehensive Trip Histories:
#
#     Trip Duration (seconds)
#     Start Time and Date
#     Stop Time and Date
#     Start Station Name & ID
#     End Station Name & ID
#     Bike ID
#     User Type (Casual = Single Trip or Day Pass user; Member = Annual or Monthly Member)
#     Birth Year
#     Gender, self-reported by member (Zero=unknown; 1=male; 2=female)
#
#
# Bluebike Stations:
#
#     Number
#     Name
#     Latitude/Longitude
#     Municipality
#     Total docks
#     Deployment Year

# %%
import pandas as pd
import geopandas as gpd
import requests
from zipfile import ZipFile
import numpy as np
import os

# %% [markdown]
# ## Loading Station Data

# %%
bike_station_url = 'https://s3.amazonaws.com/hubway-data/current_bluebikes_stations.csv'


station_df = pd.read_csv(bike_station_url, header=[0,1])
last_updated_station_date = station_df.columns[1][0]

print('Station Last Updated: ',last_updated_station_date)
station_df = station_df.droplevel(0, axis=1)

station_df.head()
# Out:
# Station Last Updated:  08/05/2022
#    Number                                 Name   Latitude  Longitude  \
# 0  K32015                       1200 Beacon St  42.344149 -71.114674
# 1  W32006                          160 Arsenal  42.364664 -71.175694
# 2  A32019                     175 N Harvard St  42.363796 -71.129164
# 3  S32035                        191 Beacon St  42.380323 -71.108786
# 4  C32094  2 Hummingbird Lane at Olmsted Green  42.288870 -71.095003
#
#      District Public  Total docks  Deployment Year
# 0   Brookline    Yes           15           2021.0
# 1   Watertown    Yes           11           2021.0
# 2      Boston    Yes           18           2014.0
# 3  Somerville    Yes           19           2018.0
# 4      Boston    Yes           17           2020.0

# %% [markdown]
# ## Loading Comprehensive History Data

# %%
from requests_html import AsyncHTMLSession

u = "https://s3.amazonaws.com/hubway-data/index.html"


session = AsyncHTMLSession()


resp = await session.get(u)
await resp.html.arender(timeout=6000, sleep=3) 
html = resp.html.raw_html

df_url_list = pd.read_html(html)[0]

# %%
df_url_list['Date Modified'] = pd.to_datetime(df_url_list['Date Modified'])
df_url_list = df_url_list.sort_values(by='Date Modified', ascending=False).reset_index(drop=True)
df_url_list.head(26)
# Out:
#                               Name       Date Modified      Size      Type
# 0   current_bluebikes_stations.csv 2022-08-05 18:41:44     34 KB  CSV file
# 1    202207-bluebikes-tripdata.zip 2022-08-05 18:41:43  10.80 MB  ZIP file
# 2    202206-bluebikes-tripdata.zip 2022-07-15 11:19:44  16.67 MB  ZIP file
# 3    202205-bluebikes-tripdata.zip 2022-06-03 22:21:03  14.86 MB  ZIP file
# 4    202204-bluebikes-tripdata.zip 2022-05-03 12:40:48  11.33 MB  ZIP file
# 5    202203-bluebikes-tripdata.zip 2022-04-06 13:20:48   7.48 MB  ZIP file
# 6    202202-bluebikes-tripdata.zip 2022-03-02 16:27:48   4.42 MB  ZIP file
# 7    202201-bluebikes-tripdata.zip 2022-02-02 12:02:56   3.28 MB  ZIP file
# 8    202110-bluebikes-tripdata.zip 2022-01-13 11:29:14  16.41 MB  ZIP file
# 9    202112-bluebikes-tripdata.zip 2022-01-06 11:45:51   5.79 MB  ZIP file
# 10   202111-bluebikes-tripdata.zip 2021-12-10 10:21:23  10.26 MB  ZIP file
# 11   202109-bluebikes-tripdata.zip 2021-10-04 13:31:10  17.82 MB  ZIP file
# 12   202108-bluebikes-tripdata.zip 2021-09-08 16:04:33  15.01 MB  ZIP file
# 13   202107-bluebikes-tripdata.zip 2021-08-14 02:21:30  12.96 MB  ZIP file
# 14   202106-bluebikes-tripdata.zip 2021-07-15 19:28:02  13.02 MB  ZIP file
# 15   202105-bluebikes-tripdata.zip 2021-06-11 13:20:25  11.19 MB  ZIP file
# 16   202104-bluebikes-tripdata.zip 2021-05-07 11:00:15   7.65 MB  ZIP file
# 17   202103-bluebikes-tripdata.zip 2021-04-08 10:35:13   5.54 MB  ZIP file
# 18   202102-bluebikes-tripdata.zip 2021-03-09 19:48:22   2.37 MB  ZIP file
# 19   202101-bluebikes-tripdata.zip 2021-02-08 10:13:21   2.84 MB  ZIP file
# 20   202012-bluebikes-tripdata.zip 2021-01-05 09:27:19   2.94 MB  ZIP file
# 21   202011-bluebikes-tripdata.zip 2020-12-04 18:27:57   6.58 MB  ZIP file
# 22   201908-bluebikes-tripdata.zip 2020-11-17 11:38:21  13.24 MB  ZIP file
# 23   201907-bluebikes-tripdata.zip 2020-11-17 11:38:15  12.24 MB  ZIP file
# 24   201906-bluebikes-tripdata.zip 2020-11-17 11:32:44  10.48 MB  ZIP file
# 25   202010-bluebikes-tripdata.zip 2020-11-04 09:54:12  10.22 MB  ZIP file

# %%
# Selecting the n most recent files for download
# WARNING: ONLY IMPLEMENTED A SIMPLE CHECK
# IF A FILE WAS IN GB THIS WOULD COMPLETELY MISS IT
# SHOULD UPDATE
n_recent_files = 12
total_download_size = df_url_list.loc[(df_url_list.Type == 'ZIP file')].Size[:n_recent_files].apply(lambda x: float(x.split(' ')[0])).sum()
print('Total Download size of: ' + str(total_download_size) + 'MB' )
# Out:
# Total Download size of: 134.13MB

# %%
zip_files_to_download = df_url_list.loc[(df_url_list.Type == 'ZIP file')].Name[:n_recent_files]
zip_files_to_download
# Out:
# 1     202207-bluebikes-tripdata.zip
# 2     202206-bluebikes-tripdata.zip
# 3     202205-bluebikes-tripdata.zip
# 4     202204-bluebikes-tripdata.zip
# 5     202203-bluebikes-tripdata.zip
# 6     202202-bluebikes-tripdata.zip
# 7     202201-bluebikes-tripdata.zip
# 8     202110-bluebikes-tripdata.zip
# 9     202112-bluebikes-tripdata.zip
# 10    202111-bluebikes-tripdata.zip
# 11    202109-bluebikes-tripdata.zip
# 12    202108-bluebikes-tripdata.zip
# Name: Name, dtype: object

# %%
bike_comp_folder = 'data/comp_monthly/'

# %%
# Takes a while to download, theres likely a more effective means

def download_bike_comprehensive(file, save_folder):

    bike_comp_url = 'https://s3.amazonaws.com/hubway-data/%s' %(file)
    bike_comp_zipfile = save_folder + file


    r = requests.get(bike_comp_url)
    with open(bike_comp_zipfile , 'wb') as f:
        f.write(r.content)

    with ZipFile(bike_comp_zipfile, 'r') as zObject:
        zObject.extractall(path = save_folder) 


    if os.path.exists(bike_comp_zipfile):
        os.remove(bike_comp_zipfile)
    else:
        print("Error: The file does not exist") 

[download_bike_comprehensive(file, bike_comp_folder) for file in zip_files_to_download]

print('Done!')
# Out:
# [None, None, None, None, None, None, None, None, None, None, None, None]

# %%
# optional: if you don't like the __MACOSX folder

# import shutil
# if os.path.exists(bike_comp_folder + '/__MACOSX'):
#     shutil.rmtree(bike_comp_folder + '/__MACOSX')
# else:
#     print('Error: The file does not exist')



# I debated on how to sort the file_paths

# def sorted_ls(path):
#     mtime = lambda f: os.stat(os.path.join(path, f)).st_mtime
#     return list(sorted(os.listdir(path), key=mtime))

# bike_comp_file_paths = sorted_ls(bike_comp_folder)

# %%
bike_comp_file_paths = [bike_comp_folder + file[:-4] + '.csv' for file in zip_files_to_download]
bike_comp_file_paths
# Out:
# ['data/comp_monthly/202207-bluebikes-tripdata.csv',
#  'data/comp_monthly/202206-bluebikes-tripdata.csv',
#  'data/comp_monthly/202205-bluebikes-tripdata.csv',
#  'data/comp_monthly/202204-bluebikes-tripdata.csv',
#  'data/comp_monthly/202203-bluebikes-tripdata.csv',
#  'data/comp_monthly/202202-bluebikes-tripdata.csv',
#  'data/comp_monthly/202201-bluebikes-tripdata.csv',
#  'data/comp_monthly/202110-bluebikes-tripdata.csv',
#  'data/comp_monthly/202112-bluebikes-tripdata.csv',
#  'data/comp_monthly/202111-bluebikes-tripdata.csv',
#  'data/comp_monthly/202109-bluebikes-tripdata.csv',
#  'data/comp_monthly/202108-bluebikes-tripdata.csv']

# %% [markdown]
# # Further edits and testing

# %%
pd.read_csv(bike_comp_file_paths[0])
# Out:
#         tripduration                 starttime                  stoptime  \
# 0                604  2020-07-01 00:00:02.6570  2020-07-01 00:10:07.5220
# 1                269  2020-07-01 00:00:03.8580  2020-07-01 00:04:33.4070
# 2                794  2020-07-01 00:00:16.7790  2020-07-01 00:13:30.9210
# 3                736  2020-07-01 00:00:20.3000  2020-07-01 00:12:36.5470
# 4                930  2020-07-01 00:00:23.1080  2020-07-01 00:15:53.3010
# ...              ...                       ...                       ...
# 258582           245  2020-07-31 23:59:52.4850  2020-08-01 00:03:57.7810
# 258583           975  2020-07-31 23:59:54.7800  2020-08-01 00:16:10.3610
# 258584           695  2020-07-31 23:59:55.2380  2020-08-01 00:11:31.0890
# 258585           978  2020-07-31 23:59:56.3810  2020-08-01 00:16:15.2230
# 258586           262  2020-07-31 23:59:58.0830  2020-08-01 00:04:21.0080
#
#         start station id                                 start station name  \
# 0                    107                                 Ames St at Main St
# 1                     46  Christian Science Plaza - Massachusetts Ave at...
# 2                      6                             Cambridge St at Joy St
# 3                     14    HMS/HSPH - Avenue Louis Pasteur at Longwood Ave
# 4                     61                        Boylston St at Fairfield St
# ...                  ...                                                ...
# 258582               363                        Harrison Ave at Mullins Way
# 258583               150                     State Street at Channel Center
# 258584               141                                     Kendall Street
# 258585               150                     State Street at Channel Center
# 258586                80            MIT Stata Center at Vassar St / Main St
#
#         start station latitude  start station longitude  end station id  \
# 0                    42.362500               -71.088220              97
# 1                    42.343666               -71.085824              33
# 2                    42.361257               -71.065287             177
# 3                    42.337417               -71.102861             332
# 4                    42.349082               -71.081924             161
# ...                        ...                      ...             ...
# 258582               42.345216               -71.063840              26
# 258583               42.344137               -71.052608              47
# 258584               42.363560               -71.082168             352
# 258585               42.344137               -71.052608              47
# 258586               42.362131               -71.091156              68
#
#                                          end station name  \
# 0       Harvard University River Houses at DeWolfe St ...
# 1                                          Kenmore Square
# 2                                         University Park
# 3                              Harvard Ave at Brainerd Rd
# 4                                      W Broadway at D St
# ...                                                   ...
# 258582                        Washington St at Waltham St
# 258583                             Cross St at Hanover St
# 258584                                            Ring Rd
# 258585                             Cross St at Hanover St
# 258586              Central Square at Mass Ave / Essex St
#
#         end station latitude  end station longitude  bikeid    usertype  \
# 0                  42.369206             -71.117106    3309  Subscriber
# 1                  42.348706             -71.097009    5467  Subscriber
# 2                  42.362648             -71.100061    5759    Customer
# 3                  42.349530             -71.130228    2914  Subscriber
# 4                  42.339109             -71.051443    2398    Customer
# ...                      ...                    ...     ...         ...
# 258582             42.341575             -71.068904    4406  Subscriber
# 258583             42.362811             -71.056067    5456    Customer
# 258584             42.348278             -71.080449    3525  Subscriber
# 258585             42.362811             -71.056067    2149    Customer
# 258586             42.365070             -71.103100    3070  Subscriber
#
#        postal code
# 0            02142
# 1            02135
# 2            02139
# 3            02134
# 4            02127
# ...            ...
# 258582       02118
# 258583       02127
# 258584       02199
# 258585       02127
# 258586       02139
#
# [258587 rows x 14 columns]
